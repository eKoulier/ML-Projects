# %% [markdown]
# # Machine Learning Engineer Nanodegree
# ## Reinforcement Learning
# ## Project: Train a Smartcab to Drive
#
# Welcome to the Reainforcement Learning project of the Machine Learning Engineer Nanodegree! In this notebook, some template code has already been provided by Udacity to aid in the analysis of the *Smartcab* and to implement the learning algorithm. Most of my work is done in the answers to each of the questions and the implementation I provide in `agent.py`.

# %% [markdown]
# -----
#
# ## Getting Started
# In this project, I work towards constructing an optimized Q-Learning driving agent that will navigate a *Smartcab* through its environment towards a goal. Since the *Smartcab* is expected to drive passengers from one location to another, the driving agent will be evaluated on two very important metrics: **Safety** and **Reliability**. A driving agent that gets the *Smartcab* to its destination while running red lights or narrowly avoiding accidents would be considered **unsafe**. Similarly, a driving agent that frequently fails to reach the destination in time would be considered **unreliable**. Maximizing the driving agent's **safety** and **reliability** would ensure that *Smartcabs* have a permanent place in the transportation industry.
#
# **Safety** and **Reliability** are measured using a letter-grade system as follows:
#
# | Grade 	| Safety 	| Reliability 	|
# |:-----:	|:------:	|:-----------:	|
# |   A+  	|  Agent commits no traffic violations,<br/>and always chooses the correct action. | Agent reaches the destination in time<br />for 100% of trips. |
# |   A   	|  Agent commits few minor traffic violations,<br/>such as failing to move on a green light. | Agent reaches the destination on time<br />for at least 90% of trips. |
# |   B   	| Agent commits frequent minor traffic violations,<br/>such as failing to move on a green light. | Agent reaches the destination on time<br />for at least 80% of trips. |
# |   C   	|  Agent commits at least one major traffic violation,<br/> such as driving through a red light. | Agent reaches the destination on time<br />for at least 70% of trips. |
# |   D   	| Agent causes at least one minor accident,<br/> such as turning left on green with oncoming traffic.       	| Agent reaches the destination on time<br />for at least 60% of trips. |
# |   F   	|  Agent causes at least one major accident,<br />such as driving through a red light with cross-traffic.      	| Agent fails to reach the destination on time<br />for at least 60% of trips. |
#
# To assist evaluating these important metrics, I will need to load visualization code that will be used later on in the project. Run the code cell below to import this code which is required for our analysis.

# %%
# Import the visualization code by Udacity
import visuals as vs

# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# ### Understand the World
# Before starting to work on implementing my driving agent, it's necessary to first understand the world (environment) which the *Smartcab* and driving agent work in. One of the major components to building a self-learning agent is understanding the characteristics about the agent, which includes how the agent operates. To begin, simply run the `agent.py` agent code exactly how it is -- no need to make any additions whatsoever. Let the resulting simulation run for some time to see the various working components. Note that in the visual simulation (if enabled), the **white vehicle** is the *Smartcab*.

# %% [markdown]
# ### Question 1
# - *Does the Smartcab move at all during the simulation?*
# - *What kind of rewards is the driving agent receiving?*
# - *How does the light changing color affect the rewards?*

# %% [markdown]
# **Answer:**
#
# <img src="environmentScreenshot.png">
#
# The simulation was run and the dynamics of the city traffic were understood.
#
# The city is a grid, where there is a light on each intersection. The light is represented by a red line indicating that the car should not pass.
#
# There is additional traffic around the city. Each car takes an action every time that the clock advances. The possible actions are: idle, turn right, turn left or move forward.
#
# The smartcab is placed at random at the beginning of the simulation. The smartcab is represented by the white vehicle. In this simulation the smartcab did not move. This can be explained by the fact that the car is always taking the action 'None'.
#
# Each time the clock advances, the car is given a reward based on its actions. The reward can be positive or negative, depending on the safety and reliability metrics. Since the car is not moving at the moment, it takes a negative reward whenever there is a green light (it should be moving to the goal) and it takes a positive reward on red lights.

# %% [markdown]
# ### Understand the Code
# In addition to understanding the world, it is also necessary to understand the code itself that governs how the world, simulation, and so on operate. Attempting to create a driving agent would be difficult without having at least explored the *"hidden"* devices that make everything work. In the `/smartcab/` top-level directory, there are two folders: `/logs/` (which will be used later) and `/smartcab/`.

# %% [markdown]
# ### Question 2
# - *In the *`agent.py`* Python file, choose three flags that can be set and explain how they change the simulation.*
# - *In the *`environment.py`* Python file, what Environment class function is called when an agent performs an action?*
# - *In the *`simulator.py`* Python file, what is the difference between the *`'render_text()'`* function and the *`'render()'`* function?*
# - *In the *`planner.py`* Python file, will the *`'next_waypoint()`* function consider the North-South or East-West direction first?*

# %% [markdown]
# **Answer:**
#
# - agent.py
#
#
# 1. grid_size: discrete number of intersections (columns, rows), default is (8, 6). This flag can be used to change the size of the environment.
# 2. enforce_deadline: set to True to enforce a deadline metric. This flag can be used to impose a final time.
# 3. update_delay: continuous time (in seconds) between actions, default is 2.0 seconds. This flag can be used to change the time between each step of the simulation.
#
# - environment.py
#
# The action called when an agent performs an action is act(self, agent, action). This function considers an action and performs the action if it is legal. Then, the cab receives a reward based on traffic laws.
#
# - simulator.py
#
#
# The render() function is the graphical render of the environment. This function visually displays the environment.
#
# The render_text() function is the text based render of the simulation. This means that the simulation is shown in text on the console.
#
# - planner.py
#
# First the function considers if the destination is at location. Then, the function considers if the destination is East or West of location. After, the function considers if the destination is North or South of location.

# %% [markdown]
# -----
# ## Implement a Basic Driving Agent
#
# The first step to creating an optimized Q-Learning driving agent is getting the agent to actually take valid actions. In this case, a valid action is one of `None`, (do nothing) `'left'` (turn left), `right'` (turn right), or `'forward'` (go forward). For my first implementation, navigate to the `'choose_action()'` agent function and make the driving agent randomly choose one of these actions. Note that I have access to several class variables that will help me write this functionality, such as `'self.learning'` and `'self.valid_actions'`. Once implemented, run the agent file and simulation briefly to confirm that my driving agent is taking a random action each time step.

# %% [markdown]
# ### Basic Agent Simulation Results
# To obtain results from the initial simulation, I will need to adjust following flags:
# - `'enforce_deadline'` - Set this to `True` to force the driving agent to capture whether it reaches the destination in time.
# - `'update_delay'` - Set this to a small value (such as `0.01`) to reduce the time between steps in each trial.
# - `'log_metrics'` - Set this to `True` to log the simluation results as a `.csv` file in `/logs/`.
# - `'n_test'` - Set this to `'10'` to perform 10 testing trials.
#
# Once I have successfully completed the initial simulation (there should have been 20 training trials and 10 testing trials), I run the code cell below to visualize the results. Note that log files are overwritten when identical simulations are run, so be careful with what log file is being loaded!
# I run the agent.py file after setting the flags from projects/smartcab folder instead of projects/smartcab/smartcab.

# %%
# Load the 'sim_no-learning' log file from the initial simulation results
vs.plot_trials('sim_no-learning.csv')

# %% [markdown]
# ### Question 3
# - *How frequently is the driving agent making bad decisions? How many of those bad decisions cause accidents?*
# - *Given that the agent is driving randomly, does the rate of reliability make sense?*
# - *What kind of rewards is the agent receiving for its actions? Do the rewards suggest it has been penalized heavily?*
# - *As the number of trials increases, does the outcome of results change significantly?*
# - *Would this Smartcab be considered safe and/or reliable for its passengers? Why or why not?*

# %% [markdown]
# **Answer:**
#
# After setting the necessary flags for the initial simulation, learning was disabled for the smartcab. The cab is currently taking a random action at each of the intersections.
#
# First, the upper left plot is the 10-trial rolling relative frequency of bad actions. This plot shows that the Total bad actions occur around 0.35 to 0.4. Other bad actions happen with less relative frequency in the order: Major violation, Minor violation, and Minor and Major accidents at a similar rate. It is expected that major violations occur with a higher rate, since it is very likely for the random cab to try to cross on red lights. This graph confirms that the cab is not learning the rules, since there is no improvement for these metrics.
#
# The upper right plot is the 10 trial rolling average reward per action. This plot shows the rewards throughout the trials. From this plot we can observe that the cab always has a negative reward. This is caused by the fact that the cab takes random actions, so the cab doesn't reach the destination and commits many traffic violations.
#
# The lower left plot is the 10-Trial rolling rate of reliability. This plot shows that the reliability never improves, and oscillates around 20%. This confirms that the cab is not learning.
#
# This random implementation of the smartcab performs poorly in Safety and Reliability, which are rates F. Since the cab is making random choices and not learning, this is expected. This means that the cab is not asfe or reliable for passengers.

# %% [markdown]
# -----
# ## Inform the Driving Agent
# The second step to creating an optimized Q-learning driving agent is defining a set of states that the agent can occupy in the environment. Depending on the input, sensory data, and additional variables available to the driving agent, a set of states can be defined for the agent so that it can eventually *learn* what action it should take when occupying a state. The condition of `'if state then action'` for each state is called a **policy**, and is ultimately what the driving agent is expected to learn. Without defining states, the driving agent would never understand which action is most optimal -- or even what environmental variables and conditions it cares about!

# %% [markdown]
# ### Identify States
# Inspecting the `'build_state()'` agent function shows that the driving agent is given the following data from the environment:
# - `'waypoint'`, which is the direction the *Smartcab* should drive leading to the destination, relative to the *Smartcab*'s heading.
# - `'inputs'`, which is the sensor data from the *Smartcab*. It includes
#   - `'light'`, the color of the light.
#   - `'left'`, the intended direction of travel for a vehicle to the *Smartcab*'s left. Returns `None` if no vehicle is present.
#   - `'right'`, the intended direction of travel for a vehicle to the *Smartcab*'s right. Returns `None` if no vehicle is present.
#   - `'oncoming'`, the intended direction of travel for a vehicle across the intersection from the *Smartcab*. Returns `None` if no vehicle is present.
# - `'deadline'`, which is the number of actions remaining for the *Smartcab* to reach the destination before running out of time.

# %% [markdown]
# ### Question 4
# *Which features available to the agent are most relevant for learning both **safety** and **efficiency**? Why are these features appropriate for modeling the *Smartcab* in the environment? If you did not choose some features, why are those features* not *appropriate? Please note that whatever features you eventually choose for your agent's state, must be argued for here. That is: your code in agent.py should reflect the features chosen in this answer.
# *
#
# NOTE: I am not allowed to engineer new features for the smartcab.

# %% [markdown]
# **Answer:**
#
# The variables that are chosen should contribute to the cab's ability to be safe and reliable. If a variable is chosen, this will make the state space larger. For this reason, only the absolutely necessary features should be chosen.
#
# | Feature | Explanation | Action | Reason |
# |:-------:|:-----------:|:------:|:------:|
# | waypoint |  Direction the Smartcab should drive leading to the destination | Include | The cab needs this variable to navigate correctly to the destination. |
# | inputs-light | The color of the light | Include | The information about the light is needed to proceed on green and stop on red |
# | inputs-left | The intended direction of travel for a vehicle to the Smartcab's left. | Include | The car can turn right on a red light. This information is needed to determine if this turn is allowed.   |
# | inputs-right | The intended direction of travel for a vehicle to the Smartcab's right | Exclude | The actions of the cab on the right are not relevant for the smartcab. The direction of the car on the right has no useful information.|
# | inputs-oncoming | The intended direction of travel for a vehicle across the intersection from the Smartcab. | Include | This information is needed in case that the cab needs to go left on a green light. If there is incoming traffic, this turn is not allowed. |
# | deadline |  The number of actions remaining for the Smartcab to reach the destination before running out of time. | Exclude | The deadline is not necessary for the cab to arrive safely or reliably. The cab should try to get to the destination as fast as possible, regardless of the remaining time. |

# %% [markdown]
# ### Define a State Space
# When defining a set of states that the agent can occupy, it is necessary to consider the *size* of the state space. That is to say, if we expect the driving agent to learn a **policy** for each state, we would need to have an optimal action for *every* state the agent can occupy. If the number of all possible states is very large, it might be the case that the driving agent never learns what to do in some states, which can lead to uninformed decisions. For example, consider a case where the following features are used to define the state of the *Smartcab*:
#
# `('is_raining', 'is_foggy', 'is_red_light', 'turn_left', 'no_traffic', 'previous_turn_left', 'time_of_day')`.
#
# How frequently would the agent occupy a state like `(False, True, True, True, False, False, '3AM')`? Without a near-infinite amount of time for training, it's doubtful the agent would ever learn the proper action!

# %% [markdown]
# ### Question 5
# *If a state is defined using the features you've selected from **Question 4**, what would be the size of the state space? Given what you know about the environment and how it is simulated, do you think the driving agent could learn a policy for each possible state within a reasonable number of training trials?*

# %% [markdown]
# **Answer:**
#
# The size of the state space is calculated by finding all the combinations of possible states.
#
# To determine the size of the state space, these are the possible states from the chosen variables:
#
# | Feature  | Possible states | Number of options  |
# |:--------:|:------------------------------|---|
# | waypoint | Forward, left and right       | 3 |
# | input-light | Red or green                  | 2 |
# | input-left | None, forward, left and right | 4 |
# | input-oncoming | None, forward, left and right | 4 |
#
# The size of the state space is 3 x 2 x 4 x 4 = 96.
#
# THe cab can make one of four decisions at each state. This means that there are 96 x 4 = 384 possible pairs of states and decisions.
#
# This size will impact the amount of simulations that need to be performed. From the calculated size it seems reasonable that the driving agent can learn a policy in a finite number of trials.

# %% [markdown]
# ### Update the Driving Agent State
# For the second implementation, I navigate to the `'build_state()'` agent function. With the justification I provided in **Question 4**, I will now set the `'state'` variable to a tuple of all the features necessary for Q-Learning.

# %% [markdown]
# -----
# ## Implement a Q-Learning Driving Agent
# The third step to creating an optimized Q-Learning agent is to begin implementing the functionality of Q-Learning itself. The concept of Q-Learning is fairly straightforward: For every state the agent visits, create an entry in the Q-table for all state-action pairs available. Then, when the agent encounters a state and performs an action, update the Q-value associated with that state-action pair based on the reward received and the iterative update rule implemented. Of course, additional benefits come from Q-Learning, such that we can have the agent choose the *best* action for each state based on the Q-values of each state-action pair possible. For this project, I will be implementing a *decaying,* $\epsilon$*-greedy* Q-learning algorithm with *no* discount factor. Follow the implementation instructions under each **TODO** in the agent functions.
#
# Note that the agent attribute `self.Q` is a dictionary: This is how the Q-table will be formed. Each state will be a key of the `self.Q` dictionary, and each value will then be another dictionary that holds the *action* and *Q-value*. Here is an example:
#
# ```
# { 'state-1': {
#     'action-1' : Qvalue-1,
#     'action-2' : Qvalue-2,
#      ...
#    },
#   'state-2': {
#     'action-1' : Qvalue-1,
#      ...
#    },
#    ...
# }
# ```
#
# Furthermore, note that we are expected to use a *decaying* $\epsilon$ *(exploration) factor*. Hence, as the number of trials increases, $\epsilon$ should decrease towards 0. This is because the agent is expected to learn from its behavior and begin acting on its learned behavior. Additionally, The agent will be tested on what it has learned after $\epsilon$ has passed a certain threshold (the default threshold is 0.05). For the initial Q-Learning implementation, I will be implementing a linear decaying function for $\epsilon$.

# %% [markdown]
# ### Q-Learning Simulation Results
# To obtain results from the initial Q-Learning implementation, I will need to adjust the following flags and setup:
# - `'enforce_deadline'` - Set this to `True` to force the driving agent to capture whether it reaches the destination in time.
# - `'update_delay'` - Set this to a small value (such as `0.01`) to reduce the time between steps in each trial.
# - `'log_metrics'` - Set this to `True` to log the simluation results as a `.csv` file and the Q-table as a `.txt` file in `/logs/`.
# - `'n_test'` - Set this to `'10'` to perform 10 testing trials.
# - `'learning'` - Set this to `'True'` to tell the driving agent to use the Q-Learning implementation.
#
# In addition, use the following decay function for $\epsilon$:
#
# $$ \epsilon_{t+1} = \epsilon_{t} - 0.05, \hspace{10px}\textrm{for trial number } t$$
#
# In case of having difficulty getting my implementation to work, I will try setting the `'verbose'` flag to `True` to help debug. Flags that have been set here should be returned to their default setting when debugging. It is important that we understand what each flag does and how it affects the simulation!
#
# Once I have successfully completed the initial Q-Learning simulation, run the code cell below to visualize the results. Note that log files are overwritten when identical simulations are run, so be careful with what log file is being loaded!

# %%
# Load the 'sim_default-learning' file from the default Q-Learning simulation
vs.plot_trials('sim_default-learning.csv')

# %% [markdown]
# ### Question 6
#
# - *Are there any observations that are similar between the basic driving agent and the default Q-Learning agent?*
# - *Approximately how many training trials did the driving agent require before testing? Does that number make sense given the epsilon-tolerance?*
# - *Is the decaying function you implemented for $\epsilon$ (the exploration factor) accurately represented in the parameters panel?*
# - *As the number of training trials increased, did the number of bad actions decrease? Did the average reward increase?*
# - *How does the safety and reliability rating compare to the initial driving agent?*

# %% [markdown]
# **Answer:**
#
# After setting the necessary flags for the default simulation, learning was enabled for the smartcab. The cab is currently using the Q-learning algorithm to learn how to get safely and promptly to the destination.
#
# First, the upper left plot is the 10-trial rolling relative frequency of bad actions. This plot shows that the number of Total bad actions is decreasing as the trials are completed. This means that the cab is appropriately learning how to avoid bad actions. Major and minor violations are decreasing relatively faster compared to major and minor accidents. This means that accidents are still happening. This can mean that more trials are needed to appropriately learn the traffic rules.
#
# The upper right plot is the 10 trial rolling average reward per action. This plot shows the rewards throughout the trials. From this plot we can observe that the rewards are increasing with time. Nevertheless, the rewards are still negative, even after learning.
#
# The lower left plot is the 10-Trial rolling rate of reliability. This plot shows that the cab is becoming more reliable with time. The reliability rate is increasing, which means that the cab is learning how to reach the destination. This is evidence that the cab is learning to choose waypoint as the direction.
#
# From these plots it can be seen that the cab is learning how to get to the destination, but still is taking many bad actions. This is confirmed by the ratings, which show high reliability but low safety.
#
# The parameter value plot shows that the exploration factor decreases linearly. From the initial and final values of epsilon, it is expected that the simulation runs for 20 times.
#
# These results show that the cab is learning, although many violations are being done by the cab. This result is an improvement from the random cab, but still needs to learn the traffic rules better.

# %% [markdown]
# -----
# ## Improve the Q-Learning Driving Agent
# The third step to creating an optimized Q-Learning agent is to perform the optimization! Now that the Q-Learning algorithm is implemented and the driving agent is successfully learning, it's necessary to tune settings and adjust learning paramaters so the driving agent learns both **safety** and **efficiency**. Typically this step will require a lot of trial and error, as some settings will invariably make the learning worse. One thing to keep in mind is the act of learning itself and the time that this takes: In theory, we could allow the agent to learn for an incredibly long amount of time; however, another goal of Q-Learning is to *transition from experimenting with unlearned behavior to acting on learned behavior*. For example, always allowing the agent to perform a random action during training (if $\epsilon = 1$ and never decays) will certainly make it *learn*, but never let it *act*. When improving on our Q-Learning implementation, we consider the implications it creates and whether it is logistically sensible to make a particular adjustment.

# %% [markdown]
# ### Improved Q-Learning Simulation Results
# To obtain results from the initial Q-Learning implementation, I will need to adjust the following flags and setup:
# - `'enforce_deadline'` - Set this to `True` to force the driving agent to capture whether it reaches the destination in time.
# - `'update_delay'` - Set this to a small value (such as `0.01`) to reduce the time between steps in each trial.
# - `'log_metrics'` - Set this to `True` to log the simluation results as a `.csv` file and the Q-table as a `.txt` file in `/logs/`.
# - `'learning'` - Set this to `'True'` to tell the driving agent to use the Q-Learning implementation.
# - `'optimized'` - Set this to `'True'` to tell the driving agent I are performing an optimized version of the Q-Learning implementation.
#
# Additional flags that can be adjusted as part of optimizing the Q-Learning agent:
# - `'n_test'` - Set this to some positive number (previously 10) to perform that many testing trials.
# - `'alpha'` - Set this to a real number between 0 - 1 to adjust the learning rate of the Q-Learning algorithm.
# - `'epsilon'` - Set this to a real number between 0 - 1 to adjust the starting exploration factor of the Q-Learning algorithm.
# - `'tolerance'` - set this to some small value larger than 0 (default was 0.05) to set the epsilon threshold for testing.
#
# Furthermore, use a decaying function of my choice for $\epsilon$ (the exploration factor). Note that whichever function I use, it **must decay to **`'tolerance'`** at a reasonable rate**. The Q-Learning agent will not begin testing until this occurs. Some example decaying functions (for $t$, the number of trials):
#
# $$ \epsilon = a^t, \textrm{for } 0 < a < 1 \hspace{50px}\epsilon = \frac{1}{t^2}\hspace{50px}\epsilon = e^{-at}, \textrm{for } 0 < a < 1 \hspace{50px} \epsilon = \cos(at), \textrm{for } 0 < a < 1$$
# I may also use a decaying function for $\alpha$ (the learning rate) if I so choose, however this is typically less common. If I do so, be sure that it adheres to the inequality $0 \leq \alpha \leq 1$.
#
# If I have difficulty getting my implementation to work, I will try setting the `'verbose'` flag to `True` to help debug. Flags that have been set here should be returned to their default setting when debugging.
#
# Once I have successfully completed the improved Q-Learning simulation, I run the code cell below to visualize the results. Note that log files are overwritten when identical simulations are run, so be careful with what log file is being loaded!

# %%
# Load the 'sim_improved-learning' file from the improved Q-Learning simulation
vs.plot_trials('sim_improved-learning.csv')

# %% [markdown]
# ### Question 7
# Using the visualization above that was produced from your improved Q-Learning simulation, provide a final analysis and make observations about the improved driving agent like in **Question 6**. Questions you should answer:
# - *What decaying function was used for epsilon (the exploration factor)?*
# - *Approximately how many training trials were needed for your agent before begining testing?*
# - *What epsilon-tolerance and alpha (learning rate) did you use? Why did you use them?*
# - *How much improvement was made with this Q-Learner when compared to the default Q-Learner from the previous section?*
# - *Would you say that the Q-Learner results show that your driving agent successfully learned an appropriate policy?*
# - *Are you satisfied with the safety and reliability ratings of the *Smartcab*?*

# %% [markdown]
# **Answer:**
#
# After exploring several combinations of values for alpha, tolerance and decay functions for epsilon, the simplest solution was chosen. This solution also has optimal Safety and Reliability ratings: A+. The function chosen was a linear function that decays slowlier than the previous linear function. The function chosen is:
#
# $$ \epsilon_{t+1} = \epsilon_{t} - 0.005, \hspace{10px}\textrm{for trial number } t$$
#
# The parameter alpha was maintained at the default value. This allows for comparison with other scenarios. Additionally, this value for learning rate is good to balance newly acquired information and overriding old information.
#
# The tolerance was also kept at the same value. This tolerance allows to control the number of trials before testing what the cab has learnt. This chosen value guarantees that the sufficient number of states are explored.
#
# From the chosen parameters, the number of trials performed was about 200. This number seems appropriate given the size of the state space. With this number of trials, the cab managed to get the maximum score for both reliability and safety.
#
# It is evident from all plots that the cab is learning the traffic rules and how to get to the destination. All bad actions are considerably lower than before. The reliability improves to almost 100%. Given the relatively low number of trials, the cab has managed to learn close to the optimal policy. These results are satisfactory.

# %% [markdown]
# ### Define an Optimal Policy
#
# Sometimes, the answer to the important question *"what am I trying to get my agent to learn?"* only has a theoretical answer and cannot be concretely described. Here, however, we can concretely define what it is the agent is trying to learn, and that is the U.S. right-of-way traffic laws. Since these laws are known information, we can further define, for each state the *Smartcab* is occupying, the optimal action for the driving agent based on these laws. In that case, we call the set of optimal state-action pairs an **optimal policy**. Hence, unlike some theoretical answers, it is clear whether the agent is acting "incorrectly" not only by the reward (penalty) it receives, but also by pure observation. If the agent drives through a red light, we both see it receive a negative reward but also know that it is not the correct behavior. This can be used to our advantage for verifying whether the **policy** our driving agent has learned is the correct one, or if it is a **suboptimal policy**.

# %% [markdown]
# ### Question 8
#
# 1. Please summarize what the optimal policy is for the smartcab in the given environment. What would be the best set of instructions possible given what we know about the environment?
#    _You can explain with words or a table, but you should thoroughly discuss the optimal policy._
#
# 2. Next, investigate the `'sim_improved-learning.txt'` text file to see the results of your improved Q-Learning algorithm. _For each state that has been recorded from the simulation, is the **policy** (the action with the highest value) correct for the given state? Are there any states where the policy is different than what would be expected from an optimal policy?_
#
# 3. Provide a few examples from your recorded Q-table which demonstrate that your smartcab learned the optimal policy. Explain why these entries demonstrate the optimal policy.
#
# 4. Try to find at least one entry where the smartcab did _not_ learn the optimal policy.  Discuss why your cab may have not learned the correct policy for the given state.
#
# Be sure to document your `state` dictionary below, it should be easy for the reader to understand what each state represents.

# %% [markdown]
# **Answer:**
#
# As the trials advance, the smartcab learns the traffic rules for the American system. Additionally, the cab is learning how to follow the waypoint to get to the destination. This means that an optimal policy can be explicitely described. It is the policy that follows the rules and tries to get to the destination.
#
# The policy can be described as follows:
#
# 1. On green light advance to the waypoint, unless the waypoint is left. In this case turn left only if there is no oncoming traffic turning left or going forward.
# 2. On red light always remain idle, unless waypoint is right. In this case turn right only if left is not going forward.
#
# The way in which the algorithm keeps track of the visited states and correct actions is through the Q-table.
#
# The state is stored as a tuple: (waypoint, inputs['light'], inputs['left'], inputs['oncoming'])
#
# An example of an entry in the table is:
#
# ('left', 'green', 'forward', 'left')
#  -- forward : 0.79
#  -- None : -2.69
#  -- right : 0.43
#  -- left : 2.12
#
# For each state tuple there is a score for each of the possible actions the cab can take. In the previous example the action with the highest score is left.
#
# From the inspection of the file and from the optimal policy it is evident that light and waypoint are crucial for reliability and safety. The results show that in general the cab takes the direction of the waypoint on green lights. This can be observed with the high values that the direction towards the waypoint have.
#
# Moreover, the cab registers the action as None when the light is red. An example of this behavior is:
#
# ('left', 'red', 'right', 'right')
#  -- forward : 0.00
#  -- None : 1.93
#  -- right : 0.00
#  -- left : 0.00
#
# We can also check that the cab has learnt to turn right on red:
#
# ('right', 'red', None, 'forward')
#  -- forward : -9.79
#  -- None : 0.24
#  -- right : 1.85
#  -- left : -10.87
#
# There can be found some states with unexpected behavior. For example:
#
# ('right', 'green', 'right', 'forward')
#  -- forward : 0.76
#  -- None : 0.00
#  -- right : 0.00
#  -- left : 0.00
#
#
# These anomalous states could happen because the cab has not visited that state enough to learn the appropriate policy.

# %% [markdown]
# -----
# ### Optional: Future Rewards - Discount Factor, `'gamma'`
# Curiously, as part of the Q-Learning algorithm, we were asked to **not** use the discount factor, `'gamma'` in the implementation. Including future rewards in the algorithm is used to aid in propagating positive rewards backwards from a future state to the current state. Essentially, if the driving agent is given the option to make several actions to arrive at different states, including future rewards will bias the agent towards states that could provide even more rewards. An example of this would be the driving agent moving towards a goal: With all actions and rewards equal, moving towards the goal would theoretically yield better rewards if there is an additional reward for reaching the goal. However, even though in this project, the driving agent is trying to reach a destination in the allotted time, including future rewards will not benefit the agent. In fact, if the agent were given many trials to learn, it could negatively affect Q-values!

# %% [markdown]
# ### Optional Question 9
# *There are two characteristics about the project that invalidate the use of future rewards in the Q-Learning algorithm. One characteristic has to do with the *Smartcab* itself, and the other has to do with the environment. Can you figure out what they are and why future rewards won't work for this project?*

# %% [markdown]
# **Answer:**
#
# The characteristic from the smartcab that invalidates future rewards is the fact that the start and finish points change with each trial. This means that the cab might learn how to get to specific destinations instead of a generic one. Additionally, the cab has no knowledge about the environment as a whole, it only know the best next step.The coding of future rewards needs more information about the optimal route.
#
# The characteristic from the environment that invalidates future rewards is the randomness of the setting. The lights and other vehicles change randomly, which means that the direction on one trial could be different on other trial. This can happen because it is now known what the other cabs or lights will be several turns ahead.
